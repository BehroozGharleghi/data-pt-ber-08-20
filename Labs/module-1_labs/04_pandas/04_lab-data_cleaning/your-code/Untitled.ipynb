# %%
import pandas as pd
import  numpy as np

# %%
df = pd.read_csv('../vehicles.csv')
df.head()
# Out:
#                Make                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
# how to see all the columns we have:
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year'],
#       dtype='object')

# %%
# we want to rename column make into manufacture:

df.rename(columns={'Make':'Manufacture'}, inplace = True)

# %%
df.head()
# Out:
#         Manufacture                Model  Year  Engine Displacement  \
# 0        AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1        AM General     FJ8c Post Office  1984                  4.2
# 2        AM General  Post Office DJ5 2WD  1985                  2.5
# 3        AM General  Post Office DJ8 2WD  1985                  4.2
# 4  ASC Incorporated                  GNX  1987                  3.8
#
#    Cylinders     Transmission        Drivetrain                Vehicle Class  \
# 0        4.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 1        6.0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD
# 2        4.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 3        6.0  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD
# 4        6.0  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars
#
#   Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.rename(columns={'Make':'Manufacture', 'Engine Displacement':'Displacement'}, inplace = True)
df.head()
# Out:
#         Manufacture                Model  Year  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1        AM General     FJ8c Post Office  1984           4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4  ASC Incorporated                  GNX  1987           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df['Manufacture'].head()
# Out:
# 0          AM General
# 1          AM General
# 2          AM General
# 3          AM General
# 4    ASC Incorporated
# Name: Manufacture, dtype: object

# %%
# we want to see the Ford manufacture (checking condition is always ==)
df['Manufacture'] == 'Ford'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 35947    False
# 35948    False
# 35949    False
# 35950    False
# 35951    False
# Name: Manufacture, Length: 35952, dtype: bool

# %%
# this is similar to select * from df WHERE Manufacture = 'Ford':
df[df['Manufacture'] == 'Ford']
# Out:
#       Manufacture               Model  Year  Displacement  Cylinders  \
# 11440        Ford        Aerostar Van  1986           2.3        4.0
# 11441        Ford        Aerostar Van  1986           2.3        4.0
# 11442        Ford        Aerostar Van  1986           2.8        6.0
# 11443        Ford        Aerostar Van  1986           2.8        6.0
# 11444        Ford        Aerostar Van  1986           3.0        6.0
# ...           ...                 ...   ...           ...        ...
# 14381        Ford  Windstar FWD Wagon  2000           3.0        6.0
# 14382        Ford  Windstar FWD Wagon  2000           3.8        6.0
# 14383        Ford  Windstar FWD Wagon  2001           3.8        6.0
# 14384        Ford  Windstar FWD Wagon  2002           3.8        6.0
# 14385        Ford  Windstar FWD Wagon  2003           3.8        6.0
#
#           Transmission         Drivetrain  Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd   Rear-Wheel Drive           Vans   Regular
# ...

# %%
# we want to save the above into a new table:
df_ford = df[df['Manufacture'] == 'Ford']
df_ford.head()
# Out:
#       Manufacture         Model  Year  Displacement  Cylinders  \
# 11440        Ford  Aerostar Van  1986           2.3        4.0
# 11441        Ford  Aerostar Van  1986           2.3        4.0
# 11442        Ford  Aerostar Van  1986           2.8        6.0
# 11443        Ford  Aerostar Van  1986           2.8        6.0
# 11444        Ford  Aerostar Van  1986           3.0        6.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11441     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11442  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11443     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11444     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11440          17.347895        18           22            19
# 11441          13.733750        23           26            24
# ...

# %%
df_ford_1986 = df[(df['Manufacture'] == 'Ford') & (df['Year'] == 1986)] 
df_ford_1986.head()
# Out:
#       Manufacture         Model  Year  Displacement  Cylinders  \
# 11440        Ford  Aerostar Van  1986           2.3        4.0
# 11441        Ford  Aerostar Van  1986           2.3        4.0
# 11442        Ford  Aerostar Van  1986           2.8        6.0
# 11443        Ford  Aerostar Van  1986           2.8        6.0
# 11444        Ford  Aerostar Van  1986           3.0        6.0
#
#           Transmission        Drivetrain Vehicle Class Fuel Type  \
# 11440  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11441     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11442  Automatic 4-spd  Rear-Wheel Drive          Vans   Regular
# 11443     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
# 11444     Manual 5-spd  Rear-Wheel Drive          Vans   Regular
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 11440          17.347895        18           22            19
# 11441          13.733750        23           26            24
# ...

# %%
# to get descriptive statistics:
df.describe()
# it will give us only the numeric values.
# Out:
#               Year  Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000  35952.000000  35952.000000       35952.000000
# mean    2000.71640      3.338493      5.765076          17.609056
# std       10.08529      1.359395      1.755268           4.467283
# min     1984.00000      0.600000      2.000000           0.060000
# 25%     1991.00000      2.200000      4.000000          14.699423
# 50%     2001.00000      3.000000      6.000000          17.347895
# 75%     2010.00000      4.300000      6.000000          20.600625
# max     2017.00000      8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# min        6.000000      9.000000      7.000000                37.000000
# ...

# %%
#create a new column hello and has hello every cell:
df['hello']= 'hello'
df.head()
# Out:
#         Manufacture                Model  Year  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1        AM General     FJ8c Post Office  1984           4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4  ASC Incorporated                  GNX  1987           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
# define a column that shows the age of the cars:
df['age'] = 2020 - df['Year']
df.head()
# Out:
#         Manufacture                Model  Year  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1        AM General     FJ8c Post Office  1984           4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4  ASC Incorporated                  GNX  1987           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
# to check if the previous command worked:


df['2020'] = df['age'] + df['Year']
df.head()
# Out:
#         Manufacture                Model  Year  Displacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984           2.5        4.0
# 1        AM General     FJ8c Post Office  1984           4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985           2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985           4.2        6.0
# 4  ASC Incorporated                  GNX  1987           3.8        6.0
#
#       Transmission        Drivetrain                Vehicle Class Fuel Type  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD   Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars   Premium
#
#    Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# ...

# %%
df.columns
# Out:
# Index(['Manufacture', 'Model', 'Year', 'Displacement', 'Cylinders',
#        'Transmission', 'Drivetrain', 'Vehicle Class', 'Fuel Type',
#        'Fuel Barrels/Year', 'City MPG', 'Highway MPG', 'Combined MPG',
#        'CO2 Emission Grams/Mile', 'Fuel Cost/Year', 'hello', 'age', '2020'],
#       dtype='object')

# %%
# to delete columns, we need to call it as a new data frame to see the changes:
df = df.drop('Fuel Cost/Year' , axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-c899fd1a3eb5> in <module>
#       1 # to delete columns, we need to call it as a new data frame to see the changes:
# ----> 2 df = df.drop('Fuel Cost/Year' , axis=1)
#
# D:\Anacoda\envs\kittycat\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4165             level=level,
#    4166             inplace=inplace,
# -> 4167             errors=errors,
#    4168         )
#    4169
#
# D:\Anacoda\envs\kittycat\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3876         for axis, labels in axes.items():
#    3877             if labels is not None:
# -> 3878                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3879
#    3880         if inplace:
#
# ...

# %%
# to delete multiple columns (the delete is permanent):
df = df.drop(['City MPG', 'Highway MPG'] , axis=1)

# %%
# how to rename? ask Shinan.

# %%
# apply functions to columns: to get sum of columns

df.sum()
# Out:
# Make                       AM GeneralAM GeneralAM GeneralAM GeneralASC In...
# Model                      DJ Po Vehicle 2WDFJ8c Post OfficePost Office D...
# Year                                                                71929756
# Engine Displacement                                                   120026
# Cylinders                                                             207266
# Transmission               Automatic 3-spdAutomatic 3-spdAutomatic 3-spdA...
# Drivetrain                 2-Wheel Drive2-Wheel DriveRear-Wheel DriveRear...
# Vehicle Class              Special Purpose Vehicle 2WDSpecial Purpose Veh...
# Fuel Type                  RegularRegularRegularRegularPremiumRegularRegu...
# Fuel Barrels/Year                                                     633081
# City MPG                                                              634414
# Highway MPG                                                           858557
# ...

# %%
# to sum the column year
df['Year'].sum()
# Out:
# 71929756

# %%
#to sum multiple columns: it is two parenthesis because we have to make a list of columns to calculate them. 
df[['Year', 'City MPG']].sum()
# Out:
# Year        71929756
# City MPG      634414
# dtype: int64

# %%
df[['Year', 'City MPG']].max()
# Out:
# Year        2017
# City MPG      58
# dtype: int64

# %%
# to sort:
df = df.sort_values(by = 'Year')

# to applied to the original table:
#df = df.sort_values(by = 'Year', inplace = True)

# %%
# to sort multiple columns:  
df.sort_values(by = [ 'Year', 'City MPG'])
# Out:
#             Make                 Model  Year  Engine Displacement  Cylinders  \
# 9068       Dodge        B350 Wagon 2WD  1984                  5.9        8.0
# 10916      Dodge  W100/W150 Pickup 4WD  1984                  5.9        8.0
# 11936       Ford    E250 Econoline 2WD  1984                  5.8        8.0
# 11807       Ford   E150 Club Wagon 2WD  1984                  5.8        8.0
# 10974      Dodge       W250 Pickup 4WD  1984                  5.9        8.0
# ...          ...                   ...   ...                  ...        ...
# 21134      Lexus               CT 200h  2017                  1.8        4.0
# 17058      Honda         Accord Hybrid  2017                  2.0        4.0
# 6497   Chevrolet         Malibu Hybrid  2017                  1.8        4.0
# 33278     Toyota                 Prius  2017                  1.8        4.0
# 33280     Toyota             Prius Eco  2017                  1.8        4.0
#
# ...

# %%
df.min()
# Out:
# Make                            AM General
# Model                      1-Ton Truck 2WD
# Year                                  1984
# Engine Displacement                    0.6
# Cylinders                                2
# Transmission                     Auto (AV)
# Drivetrain                   2-Wheel Drive
# Vehicle Class                 Compact Cars
# Fuel Type                              CNG
# Fuel Barrels/Year                     0.06
# City MPG                                 6
# Highway MPG                              9
# Combined MPG                             7
# CO2 Emission Grams/Mile                 37
# Fuel Cost/Year                         600
# dtype: object

# %%
# this iss to get the largest 3 entries in year:
df.nlargest(3, 'Year')
# Out:
#             Make         Model  Year  Engine Displacement  Cylinders  \
# 7781   Chevrolet      Trax AWD  2017                  1.4        4.0
# 18759   Infiniti      QX70 RWD  2017                  3.7        6.0
# 3360       Buick  Envision FWD  2017                  2.5        4.0
#
#           Transmission         Drivetrain                    Vehicle Class  \
# 7781    Automatic (S6)    All-Wheel Drive  Small Sport Utility Vehicle 4WD
# 18759   Automatic (S7)   Rear-Wheel Drive  Small Sport Utility Vehicle 2WD
# 3360   Automatic 6-spd  Front-Wheel Drive  Small Sport Utility Vehicle 2WD
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 7781    Regular          12.207778        24           30            27
# 18759   Premium          17.347895        17           24            19
# 3360    Regular          13.184400        22           29            25
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# ...

# %%
df.nlargest(3, ['Year',  'City MPG'])
# Out:
#          Make          Model  Year  Engine Displacement  Cylinders  \
# 33280  Toyota      Prius Eco  2017                  1.8        4.0
# 33278  Toyota          Prius  2017                  1.8        4.0
# 17058   Honda  Accord Hybrid  2017                  2.0        4.0
#
#                            Transmission         Drivetrain Vehicle Class  \
# 33280  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
# 33278  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
# 17058  Automatic (variable gear ratios)  Front-Wheel Drive  Midsize Cars
#
#       Fuel Type  Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 33280   Regular           5.885893        58           53            56
# 33278   Regular           6.338654        54           50            52
# 17058   Regular           6.866875        49           47            48
#
#        CO2 Emission Grams/Mile  Fuel Cost/Year
# 33280                    158.0             600
# ...

# %%
df.nsmallest(3, ['Year',  'City MPG'])
# Out:
#         Make                 Model  Year  Engine Displacement  Cylinders  \
# 9068   Dodge        B350 Wagon 2WD  1984                  5.9        8.0
# 10916  Dodge  W100/W150 Pickup 4WD  1984                  5.9        8.0
# 11936   Ford    E250 Econoline 2WD  1984                  5.8        8.0
#
#           Transmission                  Drivetrain  \
# 9068   Automatic 3-spd               2-Wheel Drive
# 10916  Automatic 3-spd  4-Wheel or All-Wheel Drive
# 11936  Automatic 3-spd               2-Wheel Drive
#
#                     Vehicle Class Fuel Type  Fuel Barrels/Year  City MPG  \
# 9068         Vans, Passenger Type   Regular          36.623333         8
# 10916  Standard Pickup Trucks 4WD   Regular          32.961000         9
# 11936            Vans, Cargo Type   Regular          36.623333         9
#
#        Highway MPG  Combined MPG  CO2 Emission Grams/Mile  Fuel Cost/Year
# 9068            10             9               987.444444            3700
# ...

# %%
# capitalise all the values in df.manufacture: upper works on a string:
df['Make'].apply(str.upper)

# now we use lambda to run the same:
#df['Make'].apply(lambda x: x.upper())
# Out:
# 0        AM GENERAL
# 16337           GMC
# 16336           GMC
# 5636      CHEVROLET
# 5637      CHEVROLET
#             ...
# 34115        TOYOTA
# 1993            BMW
# 2022            BMW
# 1996            BMW
# 20450           KIA
# Name: Make, Length: 35952, dtype: object

# %%
# in the 'Make' column replace every A with letter B
df['Make'].apply(lambda x: x.replace('a', 'b'))
# Out:
# 0        AM Generbl
# 16337           GMC
# 16336           GMC
# 5636      Chevrolet
# 5637      Chevrolet
#             ...
# 34115        Toyotb
# 1993            BMW
# 2022            BMW
# 1996            BMW
# 20450           Kib
# Name: Make, Length: 35952, dtype: object

# %%
# to make above command for multiple columns: 
# it will not work !!!!!!!!!!!!!
df[['Make', 'Vehicle Class']].apply(lambda x: x.replace('a', 'b'))
# Out:
#              Make                Vehicle Class
# 0      AM General  Special Purpose Vehicle 2WD
# 16337         GMC   Standard Pickup Trucks 4WD
# 16336         GMC   Standard Pickup Trucks 4WD
# 5636    Chevrolet   Standard Pickup Trucks 2WD
# 5637    Chevrolet   Standard Pickup Trucks 2WD
# ...           ...                          ...
# 34115      Toyota              Subcompact Cars
# 1993          BMW                 Compact Cars
# 2022          BMW              Subcompact Cars
# 1996          BMW                 Compact Cars
# 20450         Kia                   Large Cars
#
# [35952 rows x 2 columns]

# %%
df.mean()

# %%
# datafraem aggregation using groupby:
# here is the mean of each subgroup of fuel type, we will get the mean of everything based on groupped column: 
df.groupby(['Fuel Type']).mean()
# we can use it for min, max, median, sum
# Out:
#                                     Year  Engine Displacement  Cylinders  \
# Fuel Type
# CNG                          2003.200000             3.963333   6.500000
# Diesel                       1994.929748             4.188913   6.225027
# Gasoline or E85              2010.501255             4.465188   6.974059
# Gasoline or natural gas      2004.000000             4.570000   6.800000
# Gasoline or propane          2002.500000             5.400000   8.000000
# Midgrade                     2014.148649             5.536486   7.864865
# Premium                      2005.575345             3.517075   6.365286
# Premium Gas or Electricity   2014.470588             1.764706   4.235294
# Premium and Electricity      2015.700000             2.345000   4.850000
# Premium or E85               2012.917355             3.680992   6.892562
# Regular                      1998.252597             3.164540   5.420952
# Regular Gas and Electricity  2014.625000             1.950000   4.000000
# ...

# %%
df.groupby(['Fuel Type', 'Make']).mean()
# Out:
#                                               Year  Engine Displacement  \
# Fuel Type                   Make
# CNG                         Chevrolet  2004.400000             6.000000
#                             Dodge      1998.875000             4.487500
#                             Ford       2000.368421             5.063158
#                             GMC        2004.500000             6.000000
#                             Honda      2006.500000             1.738889
# ...                                            ...                  ...
# Regular Gas and Electricity Ford       2014.777778             2.000000
#                             Honda      2014.000000             2.000000
#                             Hyundai    2016.500000             2.000000
#                             Toyota     2013.500000             1.800000
# Regular Gas or Electricity  Chevrolet  2016.500000             1.500000
#
# ...

# %%
# here we make the mean of cylinders for each manufacturer: it means only mean of one column
df.groupby(['Fuel Type'])['Cylinders'].mean()
# Out:
# Fuel Type
# CNG                            6.500000
# Diesel                         6.225027
# Gasoline or E85                6.974059
# Gasoline or natural gas        6.800000
# Gasoline or propane            8.000000
# Midgrade                       7.864865
# Premium                        6.365286
# Premium Gas or Electricity     4.235294
# Premium and Electricity        4.850000
# Premium or E85                 6.892562
# Regular                        5.420952
# Regular Gas and Electricity    4.000000
# Regular Gas or Electricity     4.000000
# Name: Cylinders, dtype: float64

# %%
df.groupby(['Fuel Type'])[['Cylinders', 'City MPG']].mean()
# Out:
#                              Cylinders   City MPG
# Fuel Type
# CNG                           6.500000  15.966667
# Diesel                        6.225027  21.173436
# Gasoline or E85               6.974059  15.347280
# Gasoline or natural gas       6.800000  13.700000
# Gasoline or propane           8.000000  12.000000
# Midgrade                      7.864865  14.851351
# Premium                       6.365286  16.793166
# Premium Gas or Electricity    4.235294  30.705882
# Premium and Electricity       4.850000  24.900000
# Premium or E85                6.892562  17.305785
# Regular                       5.420952  17.970195
# Regular Gas and Electricity   4.000000  43.125000
# Regular Gas or Electricity    4.000000  43.000000

# %%
df.groupby(['Fuel Type'])[['Cylinders', 'City MPG']].agg(['mean', 'max', 'min'])
# Out:
#                             Cylinders              City MPG
#                                  mean   max  min       mean max min
# Fuel Type
# CNG                          6.500000   8.0  4.0  15.966667  27   8
# Diesel                       6.225027  10.0  4.0  21.173436  38  13
# Gasoline or E85              6.974059   8.0  4.0  15.347280  28  10
# Gasoline or natural gas      6.800000   8.0  4.0  13.700000  21  10
# Gasoline or propane          8.000000   8.0  8.0  12.000000  13  11
# Midgrade                     7.864865   8.0  6.0  14.851351  21  13
# Premium                      6.365286  16.0  2.0  16.793166  42   6
# Premium Gas or Electricity   4.235294   8.0  2.0  30.705882  41  20
# Premium and Electricity      4.850000   8.0  3.0  24.900000  37  16
# Premium or E85               6.892562  12.0  4.0  17.305785  24  11
# Regular                      5.420952  12.0  2.0  17.970195  58   7
# Regular Gas and Electricity  4.000000   4.0  4.0  43.125000  51  38
# ...

# %%
#
