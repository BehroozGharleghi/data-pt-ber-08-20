# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('housing_prices.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
df.shape # (rows, columns)
# Out:
# (1460, 81)

# %%
#this is to find the number of missing values:
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
# lets get the percentage of missing values
df.isnull().sum()/len(df)*100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
# which is the same as:
df.isnull().mean()*100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
pct_missing = df.isnull().sum() * 100 / len(df)
pct_missing

type(pct_missing)
# Out:
# pandas.core.series.Series

# %%
pct_missing
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
# make a table out of above missing values:

missing_table = pd.DataFrame({'column_name': df.columns,'percent_missing': pct_missing})
missing_table
# here df.columns refers to the exact number of columns in our dataframe
# Out:
#                  column_name  percent_missing
# Id                        Id         0.000000
# MSSubClass        MSSubClass         0.000000
# MSZoning            MSZoning         0.000000
# LotFrontage      LotFrontage        17.739726
# LotArea              LotArea         0.000000
# ...                      ...              ...
# MoSold                MoSold         0.000000
# YrSold                YrSold         0.000000
# SaleType            SaleType         0.000000
# SaleCondition  SaleCondition         0.000000
# SalePrice          SalePrice         0.000000
#
# [81 rows x 2 columns]

# %%
#Print the columns where more than 20% of values are missing.
above_20 = missing_table[missing_table['percent_missing']> 20]
above_20
# Out:
#              column_name  percent_missing
# Alley              Alley        93.767123
# FireplaceQu  FireplaceQu        47.260274
# PoolQC            PoolQC        99.520548
# Fence              Fence        80.753425
# MiscFeature  MiscFeature        96.301370

# %% [markdown]
# So from the above you already have the name of the columns you want to drop. Let's do it in less steps below:

# %% [markdown]
# # 1st and most correct way

# %%
df.shape
# Out:
# (1460, 81)

# %%
df_null = df.isnull().sum() * 100 / len(df)

# %%
df_null_cols = df_null[df_null > 20].index #get the name of the columns with more than 20% of missing values

# %%
df_null_cols
# Out:
# Index(['Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature'], dtype='object')

# %%
final_df = df.drop(df_null_cols, axis=1) #axis=1 to drop columns

# %%
final_df.shape
# Out:
# (1460, 76)

# %%
final_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# 2       0      9    2008        WD         Normal     223500
# 3       0      2    2006        WD        Abnorml     140000
# 4       0     12    2008        WD         Normal     250000
#
# [5 rows x 76 columns]

# %% [markdown]
# # 2nd way and using your 'percent_missing' row

# %%
result
# Out:
#                    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  \
# 0                   1          60        RL           65     8450    Pave
# 1                   2          20        RL           80     9600    Pave
# 2                   3          60        RL           68    11250    Pave
# 3                   4          70        RL           60     9550    Pave
# 4                   5          60        RL           84    14260    Pave
# ...               ...         ...       ...          ...      ...     ...
# 1457             1458          70        RL           66     9042    Pave
# 1458             1459          20        RL           68     9717    Pave
# 1459             1460          20        RL           75     9937    Pave
# column_name        Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street
# percent_missing     0           0         0      17.7397        0       0
#
#                    Alley  LotShape  LandContour  Utilities  ...  PoolArea  \
# 0                    NaN       Reg          Lvl     AllPub  ...         0
# 1                    NaN       Reg          Lvl     AllPub  ...         0
# 2                    NaN       IR1          Lvl     AllPub  ...         0
# 3                    NaN       IR1          Lvl     AllPub  ...         0
# 4                    NaN       IR1          Lvl     AllPub  ...         0
# ...                  ...       ...          ...        ...  ...       ...
# 1457                 NaN       Reg          Lvl     AllPub  ...         0
# 1458                 NaN       Reg          Lvl     AllPub  ...         0
# 1459                 NaN       Reg          Lvl     AllPub  ...         0
# column_name        Alley  LotShape  LandContour  Utilities  ...  PoolArea
# percent_missing  93.7671         0            0          0  ...         0
#
#                   PoolQC    Fence  MiscFeature  MiscVal  MoSold  YrSold  \
# 0                    NaN      NaN          NaN        0       2    2008
# 1                    NaN      NaN          NaN        0       5    2007
# 2                    NaN      NaN          NaN        0       9    2008
# 3                    NaN      NaN          NaN        0       2    2006
# 4                    NaN      NaN          NaN        0      12    2008
# ...                  ...      ...          ...      ...     ...     ...
# 1457                 NaN    GdPrv         Shed     2500       5    2010
# 1458                 NaN      NaN          NaN        0       4    2010
# 1459                 NaN      NaN          NaN        0       6    2008
# column_name       PoolQC    Fence  MiscFeature  MiscVal  MoSold  YrSold
# percent_missing  99.5205  80.7534      96.3014        0       0       0
#
#                  SaleType  SaleCondition  SalePrice
# 0                      WD         Normal     208500
# 1                      WD         Normal     181500
# 2                      WD         Normal     223500
# 3                      WD        Abnorml     140000
# 4                      WD         Normal     250000
# ...                   ...            ...        ...
# 1457                   WD         Normal     266500
# 1458                   WD         Normal     142125
# 1459                   WD         Normal     147500
# column_name      SaleType  SaleCondition  SalePrice
# percent_missing         0              0          0
#
# [1462 rows x 81 columns]

# %%
result.shape
# Out:
# (1462, 81)

# %%
percent_missing_mask = result.loc['percent_missing', :]<20 # access the row with .loc. the ":" represents the all 
#range of columns

# %%
percent_missing_mask #this is a "boolean" mask that we'll use to apply to the result df. False values are thrown away
# Out:
# Id               True
# MSSubClass       True
# MSZoning         True
# LotFrontage      True
# LotArea          True
#                  ...
# MoSold           True
# YrSold           True
# SaleType         True
# SaleCondition    True
# SalePrice        True
# Name: percent_missing, Length: 81, dtype: bool

# %%
percent_missing_mask.value_counts() #makes sense with the 2st way
# Out:
# True     76
# False     5
# Name: percent_missing, dtype: int64

# %%
result_transpose = result.T #lets transpose the df result so it is on the same shape of the mask

# %%
result_transpose
# Out:
#                     0       1       2        3       4       5       6  \
# Id                  1       2       3        4       5       6       7
# MSSubClass         60      20      60       70      60      50      20
# MSZoning           RL      RL      RL       RL      RL      RL      RL
# LotFrontage        65      80      68       60      84      85      75
# LotArea          8450    9600   11250     9550   14260   14115   10084
# ...               ...     ...     ...      ...     ...     ...     ...
# MoSold              2       5       9        2      12      10       8
# YrSold           2008    2007    2008     2006    2008    2009    2007
# SaleType           WD      WD      WD       WD      WD      WD      WD
# SaleCondition  Normal  Normal  Normal  Abnorml  Normal  Normal  Normal
# SalePrice      208500  181500  223500   140000  250000  143000  307000
#
#                     7        8       9  ...    1452     1453    1454    1455  \
# Id                  8        9      10  ...    1453     1454    1455    1456
# MSSubClass         60       50     190  ...     180       20      20      60
# MSZoning           RL       RM      RL  ...      RM       RL      FV      RL
# LotFrontage       NaN       51      50  ...      35       90      62      62
# LotArea         10382     6120    7420  ...    3675    17217    7500    7917
# ...               ...      ...     ...  ...     ...      ...     ...     ...
# MoSold             11        4       1  ...       5        7      10       8
# YrSold           2009     2008    2008  ...    2006     2006    2009    2007
# SaleType           WD       WD      WD  ...      WD       WD      WD      WD
# SaleCondition  Normal  Abnorml  Normal  ...  Normal  Abnorml  Normal  Normal
# SalePrice      200000   129900  118000  ...  145000    84500  185000  175000
#
#                  1456    1457    1458    1459    column_name percent_missing
# Id               1457    1458    1459    1460             Id               0
# MSSubClass         20      70      20      20     MSSubClass               0
# MSZoning           RL      RL      RL      RL       MSZoning               0
# LotFrontage        85      66      68      75    LotFrontage         17.7397
# LotArea         13175    9042    9717    9937        LotArea               0
# ...               ...     ...     ...     ...            ...             ...
# MoSold              2       5       4       6         MoSold               0
# YrSold           2010    2010    2010    2008         YrSold               0
# SaleType           WD      WD      WD      WD       SaleType               0
# SaleCondition  Normal  Normal  Normal  Normal  SaleCondition               0
# SalePrice      210000  266500  142125  147500      SalePrice               0
#
# [81 rows x 1462 columns]

# %%
# now apply the mask
result_transpose_after_mask=result_transpose[percent_missing_mask]

# %%
result_transpose_after_mask
# Out:
#                     0       1       2        3       4       5       6  \
# Id                  1       2       3        4       5       6       7
# MSSubClass         60      20      60       70      60      50      20
# MSZoning           RL      RL      RL       RL      RL      RL      RL
# LotFrontage        65      80      68       60      84      85      75
# LotArea          8450    9600   11250     9550   14260   14115   10084
# ...               ...     ...     ...      ...     ...     ...     ...
# MoSold              2       5       9        2      12      10       8
# YrSold           2008    2007    2008     2006    2008    2009    2007
# SaleType           WD      WD      WD       WD      WD      WD      WD
# SaleCondition  Normal  Normal  Normal  Abnorml  Normal  Normal  Normal
# SalePrice      208500  181500  223500   140000  250000  143000  307000
#
#                     7        8       9  ...    1452     1453    1454    1455  \
# Id                  8        9      10  ...    1453     1454    1455    1456
# MSSubClass         60       50     190  ...     180       20      20      60
# MSZoning           RL       RM      RL  ...      RM       RL      FV      RL
# LotFrontage       NaN       51      50  ...      35       90      62      62
# LotArea         10382     6120    7420  ...    3675    17217    7500    7917
# ...               ...      ...     ...  ...     ...      ...     ...     ...
# MoSold             11        4       1  ...       5        7      10       8
# YrSold           2009     2008    2008  ...    2006     2006    2009    2007
# SaleType           WD       WD      WD  ...      WD       WD      WD      WD
# SaleCondition  Normal  Abnorml  Normal  ...  Normal  Abnorml  Normal  Normal
# SalePrice      200000   129900  118000  ...  145000    84500  185000  175000
#
#                  1456    1457    1458    1459    column_name percent_missing
# Id               1457    1458    1459    1460             Id               0
# MSSubClass         20      70      20      20     MSSubClass               0
# MSZoning           RL      RL      RL      RL       MSZoning               0
# LotFrontage        85      66      68      75    LotFrontage         17.7397
# LotArea         13175    9042    9717    9937        LotArea               0
# ...               ...     ...     ...     ...            ...             ...
# MoSold              2       5       4       6         MoSold               0
# YrSold           2010    2010    2010    2008         YrSold               0
# SaleType           WD      WD      WD      WD       SaleType               0
# SaleCondition  Normal  Normal  Normal  Normal  SaleCondition               0
# SalePrice      210000  266500  142125  147500      SalePrice               0
#
# [76 rows x 1462 columns]

# %%
(result_transpose_after_mask.T).head() #let's put it back on the original shape :)
# Out:
#   Id MSSubClass MSZoning LotFrontage LotArea Street LotShape LandContour  \
# 0  1         60       RL          65    8450   Pave      Reg         Lvl
# 1  2         20       RL          80    9600   Pave      Reg         Lvl
# 2  3         60       RL          68   11250   Pave      IR1         Lvl
# 3  4         70       RL          60    9550   Pave      IR1         Lvl
# 4  5         60       RL          84   14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold YrSold SaleType SaleCondition SalePrice
# 0       0      2   2008       WD        Normal    208500
# 1       0      5   2007       WD        Normal    181500
# 2       0      9   2008       WD        Normal    223500
# 3       0      2   2006       WD       Abnorml    140000
# 4       0     12   2008       WD        Normal    250000
#
# [5 rows x 76 columns]

# %% [markdown]
# # which is the same result we got on the first way

# %%
final_df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl
#
#   Utilities LotConfig  ... EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    AllPub    Inside  ...             0         0           0        0
# 1    AllPub       FR2  ...             0         0           0        0
# 2    AllPub    Inside  ...             0         0           0        0
# 3    AllPub    Corner  ...           272         0           0        0
# 4    AllPub       FR2  ...             0         0           0        0
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# 2       0      9    2008        WD         Normal     223500
# 3       0      2    2006        WD        Abnorml     140000
# 4       0     12    2008        WD         Normal     250000
#
# [5 rows x 76 columns]
